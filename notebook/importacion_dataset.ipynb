# %% [markdown]
# Importamos archivo csv "team_details"

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\team_details.csv'
df = pd.read_csv(ruta_archivo_csv)
df.head(50)
print(f'Cantidad de equipos: {len(df)}')
# Out:
# Cantidad de equipos: 25

# %% [markdown]
# Importamos csv de team_info_common

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\team_info_common.csv'
df = pd.read_csv(ruta_archivo_csv)
df.head(50)
print(f'Cantidad de equipos: {len(df)}')
# Out:
# Cantidad de equipos: 0

# %% [markdown]
# team_details

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\team_details.csv'
df = pd.read_csv(ruta_archivo_csv)

print(f'Cantidad de equipos: {len(df)}')

df.head(50)
# Out:
# Cantidad de equipos: 25
#        team_id abbreviation       nickname  yearfounded           city  \
# 0   1610612737          ATL          Hawks       1949.0        Atlanta
# 1   1610612741          CHI          Bulls       1966.0        Chicago
# 2   1610612742          DAL      Mavericks       1980.0         Dallas
# 3   1610612743          DEN        Nuggets       1976.0         Denver
# 4   1610612744          GSW       Warriors       1946.0   Golden State
# 5   1610612745          HOU        Rockets       1967.0        Houston
# 6   1610612746          LAC       Clippers       1970.0    Los Angeles
# 7   1610612747          LAL         Lakers       1948.0    Los Angeles
# 8   1610612748          MIA           Heat       1988.0          Miami
# 9   1610612749          MIL          Bucks       1968.0      Milwaukee
# 10  1610612750          MIN   Timberwolves       1989.0      Minnesota
# 11  1610612751          BKN           Nets       1976.0       Brooklyn
# ...

# %% [markdown]
# Importacion de dataset juego, para filtrar por año.

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\game.csv'
df_juego = pd.read_csv(ruta_archivo_csv)

print(f'Cantidad de equipos: {len(df_juego)}')
# Out:
# Cantidad de equipos: 65698

# %%
# Cargamos nuevamente el data set, para "parsear" la columna 'game_date'.
df_juego = pd.read_csv(ruta_archivo_csv, parse_dates=['game_date'])

# Convertimos al formato fecha.
# df_games['game_date'] = pd.to_datetime(df_games['game_date'])
df_juego['game_date'] = pd.to_datetime(df_juego['game_date'], format='%Y-%m-%d')

print(df_juego['game_date'].dtype)


# Filtrar por fechas:
games_filtred = df_juego[
    (df_juego['game_date'] >= '2010-10-03') & ## 2010-10-03
    (df_juego['game_date'] <= '2020-10-06') ## 2020-10-06
]

# obtener el set de 'game_id' válidos
df_juego_id_validados = set(games_filtred['game_id'])
print(f'Cantidad de partidos entre 2010 y 2020: {len(df_juego_id_validados)}')

# # Muestro los tipos de datos:
# for columna in df_juego_id_validados.columns:
#     print(columna)
#     print(df_juego_id_validados[columna].describe())
#     print('------------------------------------')
# Out:
# datetime64[ns]
# Cantidad de partidos entre 2010 y 2020: 12285

# %%
games_filtred.to_csv(r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\juego.csv', index=False)

# %% [markdown]
# # ___________________________________________________

# %% [markdown]
# Cargamos dataset 'juagadas'

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\jugadas.csv'
df_jugadas = pd.read_csv(ruta_archivo_csv)

## Leemos solo la primer fila con el nombre de las columnas.
def obtener_nombre_columnas(ruta_archivo_csv):
    
    columnas = pd.read_csv(ruta_archivo_csv, nrows=0).columns.tolist()
    return columnas

primera_fila = obtener_nombre_columnas(ruta_archivo_csv)

# mostramos las columnas:
print("Columnas del archivo 'play_by_play': ")
for col in primera_fila:
    print("-", col)
print(f'Cantidad de equipos: {len(df_jugadas)}')
# Out:
# Columnas del archivo 'play_by_play':
# - fecha_del_partido
# - id_del_partido
# - tipo_de_evento
# - tipo_de_accion_evento
# - periodo
# - hora_de_acción
# - acción_del_local
# - acción_neutral
# - acción_del_visitante
# - id_jugador1
# - nombre_jugador1
# - id_equipo_jugador1
# - id_jugador2
# - nombre_jugador2
# - id_equipo_jugador2
# - id_jugador3
# - nombre_jugador3
# - id_equipo_jugador3
# Cantidad de equipos: 4271334

# %% [markdown]
# EXPLORAMOS LA TABLA JUGADOR_DETALLE

# %%
## Definimos la ruta donde se encuentra
ruta_jugador_info = r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv' 

## Leemos el dataset
df = pd.read_csv(ruta_jugador_info)

# Muestro los tipos de datos:
for columna in df.columns:
    print(columna)
    print(df[columna].describe())
    print('------------------------------------')
# Out:
# person_id
# count    4.171000e+03
# mean     3.327509e+05
# std      5.768886e+05
# min      2.000000e+00
# 25%      7.612850e+04
# 50%      7.759300e+04
# 75%      2.022745e+05
# max      1.631347e+06
# Name: person_id, dtype: float64
# ------------------------------------
# Nombre
# count     4171
# unique    1434
# top       John
# freq        77
# Name: Nombre, dtype: object
# ------------------------------------
# Apellido
# count         4171
# unique        2576
# top       Williams
# freq            67
# Name: Apellido, dtype: object
# ------------------------------------
# display_nombre_apellido
# count               4171
# unique              4139
# top       George Johnson
# freq                   3
# Name: display_nombre_apellido, dtype: object
# ------------------------------------
# Fecha_nacimiento
# count              4171
# unique             3895
# top       04-04-05 0:00
# freq                  3
# Name: Fecha_nacimiento, dtype: object
# ...

# %%
## Leemos solo la primer fila con el nombre de las columnas.
def obtener_nombre_columnas(ruta_jugador_info):
    
    columnas = pd.read_csv(ruta_jugador_info, nrows=0).columns.tolist()
    return columnas

primera_fila = obtener_nombre_columnas(ruta_jugador_info)
# mostramos las columnas:
print("Columnas del archivo 'jugador deatalle': ")
for col in primera_fila:
    print("-", col)
# Out:
# Columnas del archivo 'jugador deatalle':
# - person_id
# - Nombre
# - Apellido
# - display_nombre_apellido
# - Fecha_nacimiento
# - Pais
# - height
# - weight
# - season_exp
# - jersey
# - position
# - rosterstatus
# - games_played_current_season_flag
# - team_id
# - from_year
# - to_year

# %% [markdown]
# Parseamos DATASET para formato FECHA

# %%
# Cargamos nuevamente el data set, para "parsear" la columna 'game_date'.
df = pd.read_csv(ruta_jugador_info, parse_dates=['Fecha_nacimiento'])

# Convertimos al formato fecha.
# df_games['game_date'] = pd.to_datetime(df_games['game_date'])
df['Fecha_nacimiento'] = pd.to_datetime(df['Fecha_nacimiento'], format='%Y-%m-%d')

print(df['Fecha_nacimiento'].dtype)

# Muestro los tipos de datos:
for columna in df.columns:
    print(columna)
    print(df[columna].describe())
    print('------------------------------------')
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_7236\2759324688.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(ruta_jugador_info, parse_dates=['Fecha_nacimiento'])
# datetime64[ns]
# person_id
# count    4.171000e+03
# mean     3.327509e+05
# std      5.768886e+05
# min      2.000000e+00
# 25%      7.612850e+04
# 50%      7.759300e+04
# 75%      2.022745e+05
# max      1.631347e+06
# Name: person_id, dtype: float64
# ------------------------------------
# Nombre
# count     4171
# unique    1434
# top       John
# freq        77
# Name: Nombre, dtype: object
# ------------------------------------
# Apellido
# count         4171
# unique        2576
# top       Williams
# freq            67
# Name: Apellido, dtype: object
# ------------------------------------
# display_nombre_apellido
# count               4171
# ...

# %% [markdown]
# Cantidad de filas con team_id

# %%
import pandas as pd

# 1. Mostrar los jugadores con team_id = 0
jugadores_team_id_0 = df[df['team_id'] == 0]
print("🎯 Filas con team_id = 0:")
print(jugadores_team_id_0)
# Out:
# 🎯 Filas con team_id = 0:
#       person_id   Nombre   Apellido display_nombre_apellido Fecha_nacimiento  \
# 7        203518     Alex    Abrines            Alex Abrines       1993-01-08
# 13       203112   Quincy        Acy              Quincy Acy       1990-06-10
# 16       200801   Hassan      Adams            Hassan Adams       1984-06-20
# 17      1629121   Jaylen      Adams            Jaylen Adams       1996-04-05
# 25       202399     Jeff     Adrien             Jeff Adrien       1986-10-02
# ...         ...      ...        ...                     ...              ...
# 4148     201156     Nick      Young              Nick Young       1985-01-06
# 4159     202545     Luke     Zeller             Luke Zeller       1987-07-04
# 4162       1917     Wang    Zhi-zhi            Wang Zhi-zhi       1977-08-07
# 4163        678   George      Zidek            George Zidek       2073-02-08
# 4164       2583  Derrick  Zimmerman       Derrick Zimmerman       1981-02-12
#
# ...

# %%
# Filtrar jugadores con team_id = 0
jugadores_team_id_0 = df[df['team_id'] == 0]

# Mostrar cantidad
cantidad = jugadores_team_id_0.shape[0]
print(f"🔢 Cantidad de jugadores con team_id = 0: {cantidad}")
# Out:
# 🔢 Cantidad de jugadores con team_id = 0: 702

# %% [markdown]
# Analisis de cuantas fechas de nacimiento hay superiores al año 2000

# %%
# Filtrar por fechas posteriores a 2000-01-01
jugadores_2000 = df[df['Fecha_nacimiento'] > pd.Timestamp("2000-01-01")]
# Ordenar las fechas de menor a mayor
jugadores_2000 = jugadores_2000.sort_values(by='Fecha_nacimiento', ascending=True)

# Mostrar resultados
print("📅 Jugadores nacidos después del 01-01-2000:")
print(jugadores_2000)

# Mostrar cuántos hay
print(f"\n🔢 Total de jugadores nacidos después del 2000: {jugadores_2000.shape[0]}")
# Out:
# 📅 Jugadores nacidos después del 01-01-2000:
#       person_id  Nombre    Apellido display_nombre_apellido Fecha_nacimiento  \
# 959     1630245     Ayo     Dosunmu             Ayo Dosunmu       2000-01-17
# 275     1631262   Jules     Bernard           Jules Bernard       2000-01-21
# 1261    1629636  Darius     Garland          Darius Garland       2000-01-26
# 3933    1629632    Coby       White              Coby White       2000-02-16
# 1467    1630169  Tyrese  Haliburton       Tyrese Haliburton       2000-02-29
# ...         ...     ...         ...                     ...              ...
# 2920       2130    Mike   Penberthy          Mike Penberthy       2074-11-29
# 600         713   Chris        Carr              Chris Carr       2074-12-03
# 2062        954   Kerry     Kittles           Kerry Kittles       2074-12-06
# 2252       1732  Felipe       Lopez            Felipe Lopez       2074-12-19
# 3351       1852    Jeff    Sheppard           Jeff Sheppard       2074-12-29
#
# ...

# %% [markdown]
# Empezamos a filtrar y borrar

# %%
# Cargamos nuevamente el data set, para "parsear" la columna 'game_date'.
df = pd.read_csv(ruta_jugador_info, parse_dates=['Fecha_nacimiento'])

# Convertimos al formato fecha.
# df_games['game_date'] = pd.to_datetime(df_games['game_date'])
df['Fecha_nacimiento'] = pd.to_datetime(df['Fecha_nacimiento'], format='%Y-%m-%d')

# Asegurarse de que 'to_year' sea numérico (por si viene como texto)
df['to_year'] = pd.to_numeric(df['to_year'], errors='coerce')

# Filtrar las filas donde to_year esté entre 2010 y 2020 (inclusive)
df = df[(df['to_year'] >= 2010) & (df['to_year'] <= 2020)]

# Mostrar resultados
print("📅 Jugadores con to_year entre 2010 y 2020:")
print(df[['display_nombre_apellido', 'to_year']])

# Cantidad total
print(f"\n🔢 Total: {df.shape[0]}")

# Guardamos
df.to_csv(r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv')
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_7236\16077218.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(ruta_jugador_info, parse_dates=['Fecha_nacimiento'])
# 📅 Jugadores con to_year entre 2010 y 2020:
#      display_nombre_apellido  to_year
# 7               Alex Abrines   2018.0
# 13                Quincy Acy   2018.0
# 17              Jaylen Adams   2020.0
# 18              Jordan Adams   2015.0
# 23                 Deng Adel   2018.0
# ...                      ...      ...
# 4150               Sam Young   2012.0
# 4159             Luke Zeller   2012.0
# 4165       Stephen Zimmerman   2016.0
# 4166             Paul Zipser   2017.0
# 4167              Ante Zizic   2019.0
#
# [783 rows x 2 columns]
#
# 🔢 Total: 783

# %% [markdown]
# Filtrmos si la posicion del juador es 0., si es así la borramos

# %%
## Definimos la ruta donde se encuentra
ruta_jugador_info = r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv' 

## Leemos el dataset
df = pd.read_csv(ruta_jugador_info)

# Eliminar filas donde la columna 'position' tiene valores nulos
df = df.dropna(subset=['position'])

# Verificar cuántas filas quedaron
print(f"✅ Total de filas luego de eliminar posiciones nulas: {df.shape[0]}")


# Guardamos 
df.to_csv(r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv')
# Out:
# ✅ Total de filas luego de eliminar posiciones nulas: 766

# %% [markdown]
# Eliminamos las filas en donde la columna 'team_id' tiene valores igual a 0. NO GUARDAR TODAVÍA

# %%
import pandas as pd 
import numpy as np 

## Definimos la ruta donde se encuentra
ruta_jugador_info = r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv' 

## Leemos el dataset
df = pd.read_csv(ruta_jugador_info)

# Eliminar filas donde 'team_id' es igual a 0
df = df[df['id_equipo'] != 0]

# Verificar cuántas filas quedaron
print(f"✅ Total de filas luego de eliminar id_equipo = 0: {df.shape[0]}")
df.to_csv(r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv')
# Out:
# ✅ Total de filas luego de eliminar id_equipo = 0: 530

# %%
import pandas as pd 
import numpy as np 

## Definimos la ruta donde se encuentra
ruta_jugador_info = r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.xlsx' 

## Leemos el dataset
df_fil = pd.read_excel(ruta_jugador_info)

df_fil.to_csv(r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 ruta_jugador_info = r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.xlsx'
#       7 ## Leemos el dataset
# ----> 8 df_fil = pd.read_excel(ruta_jugador_info)
#      10 # df_fil.to_csv(r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv')
#
# File c:\Users\Fernando\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...

# %%
import pandas as pd 
import numpy as np 

## Definimos la ruta donde se encuentra
ruta_jugador_info = r'C:\Users\Fernando\Desktop\CSV de NBA\jugador detalle.csv' 

## Leemos el dataset
df = pd.read_csv(ruta_jugador_info)

# Eliminar columnas innecesarias
columnas_a_eliminar = ['Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0']
df = df.drop(columns=columnas_a_eliminar, errors='ignore')

def convertir_pies_a_cm(valor):
    try:
        # Separar en pies y pulgadas
        pies, pulgadas = str(valor).split("-")
        pies = int(pies)
        pulgadas = int(pulgadas)
        # Convertir a centímetros
        altura_cm = pies * 30.48 + pulgadas * 2.54
        return round(altura_cm, 2)
    except:
        return None

df['Altura'] = df['Altura'].apply(convertir_pies_a_cm)

# FechaNacimiento: convertir a datetime
df['FechaNacimiento'] = pd.to_datetime(df['FechaNacimiento'], errors='coerce')

# JugoEstaTemporada: convertir a booleano (N = False, Y = True)
df['JugoEstaTemporada'] = df['JugoEstaTemporada'].map({'Y': True, 'N': False})


print(df)
# Out:
#      IDJugador   Nombre   Apellido DisplaNombreApellido FechaNacimiento  \
# 0       203919   Jordan      Adams         Jordan Adams      1994-08-07
# 1      1629061     Deng       Adel            Deng Adel      1997-01-02
# 2       201167    Arron    Afflalo        Arron Afflalo      1985-10-15
# 3       201336    Blake     Ahearn         Blake Ahearn      1984-05-27
# 4       201582   Alexis     Ajinca        Alexis Ajinca      1988-06-05
# ..         ...      ...        ...                  ...             ...
# 525    1626202      Joe      Young            Joe Young      1992-06-27
# 526     201970      Sam      Young            Sam Young      1985-01-06
# 527    1627757  Stephen  Zimmerman    Stephen Zimmerman      1996-09-09
# 528    1627835     Paul     Zipser          Paul Zipser      1994-02-18
# 529    1627790     Ante      Zizic           Ante Zizic      1997-04-01
#
#             Pais  Altura  Peso  TemporadasExperiencia  NroCamiseta  \
# ...
