# %% [markdown]
# Importamos archivo csv "team_details"

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\team_details.csv'
df = pd.read_csv(ruta_archivo_csv)
df.head(50)
print(f'Cantidad de equipos: {len(df)}')
# Out:
# Cantidad de equipos: 25

# %% [markdown]
# Importamos csv de team_info_common

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\team_info_common.csv'
df = pd.read_csv(ruta_archivo_csv)
df.head(50)
print(f'Cantidad de equipos: {len(df)}')
# Out:
# Cantidad de equipos: 0

# %% [markdown]
# team_details

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\team_details.csv'
df = pd.read_csv(ruta_archivo_csv)

print(f'Cantidad de equipos: {len(df)}')

df.head(50)
# Out:
# Cantidad de equipos: 25
#        team_id abbreviation       nickname  yearfounded           city  \
# 0   1610612737          ATL          Hawks       1949.0        Atlanta
# 1   1610612741          CHI          Bulls       1966.0        Chicago
# 2   1610612742          DAL      Mavericks       1980.0         Dallas
# 3   1610612743          DEN        Nuggets       1976.0         Denver
# 4   1610612744          GSW       Warriors       1946.0   Golden State
# 5   1610612745          HOU        Rockets       1967.0        Houston
# 6   1610612746          LAC       Clippers       1970.0    Los Angeles
# 7   1610612747          LAL         Lakers       1948.0    Los Angeles
# 8   1610612748          MIA           Heat       1988.0          Miami
# 9   1610612749          MIL          Bucks       1968.0      Milwaukee
# 10  1610612750          MIN   Timberwolves       1989.0      Minnesota
# 11  1610612751          BKN           Nets       1976.0       Brooklyn
# ...

# %% [markdown]
# Importacion de dataset juego, para filtrar por año.

# %%
import pandas as pd 
import numpy as np 

ruta_archivo_csv = r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\game.csv'
df_juego = pd.read_csv(ruta_archivo_csv)

print(f'Cantidad de equipos: {len(df_juego)}')
# Out:
# Cantidad de equipos: 65698

# %%
# Cargamos nuevamente el data set, para "parsear" la columna 'game_date'.
df_juego = pd.read_csv(ruta_archivo_csv, parse_dates=['game_date'])

# Convertimos al formato fecha.
# df_games['game_date'] = pd.to_datetime(df_games['game_date'])
df_juego['game_date'] = pd.to_datetime(df_juego['game_date'], format='%Y-%m-%d')

print(df_juego['game_date'].dtype)


# Filtrar por fechas:
games_filtred = df_juego[
    (df_juego['game_date'] >= '2010-10-03') & ## 2010-10-03
    (df_juego['game_date'] <= '2020-10-06') ## 2020-10-06
]

# obtener el set de 'game_id' válidos
df_juego_id_validados = set(games_filtred['game_id'])
print(f'Cantidad de partidos entre 2010 y 2020: {len(df_juego_id_validados)}')

# # Muestro los tipos de datos:
# for columna in df_juego_id_validados.columns:
#     print(columna)
#     print(df_juego_id_validados[columna].describe())
#     print('------------------------------------')
# Out:
# datetime64[ns]
# Cantidad de partidos entre 2010 y 2020: 12285

# %%
games_filtred.to_csv(r'C:\Users\Fernando\Desktop\CSV de NBA\archive\csv\juego.csv', index=False)

# %% [markdown]
# # ___________________________________________________
